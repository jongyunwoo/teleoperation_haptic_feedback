# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
depth_data = np.load('/home/scilab/teleoperation/avp_teleoperate/teleop/utils/data/episode_0007/wrist_depths/000968_depth_0.npy')
print(depth_data.dtype)
print(depth_data)
print(depth_data.min(), depth_data.max())
zero_indices = np.argwhere(depth_data == 0)

print(f"Zero‐valued pixels: {zero_indices.shape[0]}")
zero_mask = (depth_data == 0)
# Out:
# uint16
# [[4632 4632 4632 ... 3970 3970 3970]
#  [4632 4632 4632 ... 3970 3970 3970]
#  [4632 4632 4632 ... 3970 3970 3970]
#  ...
#  [ 717  717  717 ...  439  439  751]
#  [ 717  717  717 ...  439  439  750]
#  [   0    0  717 ...  439  439  750]]
# 0 5879
# Zero‐valued pixels: 565

# %%
plt.figure(figsize=(6,4))
plt.imshow(zero_mask, cmap='gray')
plt.title("Zero‐Value Pixel Mask")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.imshow(depth_data, cmap='jet')   
plt.title("Depth")
plt.axis("off")
plt.colorbar(label="uint8 value")
plt.show()
