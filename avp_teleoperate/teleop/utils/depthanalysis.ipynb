# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
depth_data = np.load('/home/scilab/Documents/teleoperation/avp_teleoperate/teleop/utils/datanalysis/episode_0004/depths/000001_depth_0.npy')
print(depth_data.shape)
print(depth_data.dtype)
print(depth_data)
print(depth_data.min(), depth_data.max())
zero_indices = np.argwhere(depth_data == 0)

print(f"Zero‐valued pixels: {zero_indices.shape[0]}")
zero_mask = (depth_data == 0)
# Out:
# (480, 848)
# uint16
# [[2407 2398 2398 ... 1882 1872 1872]
#  [2398 2398 2398 ... 1877 1872 1872]
#  [2398 2398 2390 ... 1872 1867 1867]
#  ...
#  [ 531  531  531 ... 1272 1272    0]
#  [ 531  532  532 ... 1272 1272    0]
#  [ 532  532  532 ... 1272 1272    0]]
# 0 2626
# Zero‐valued pixels: 41407

# %%
plt.figure(figsize=(6,4))
plt.imshow(zero_mask, cmap='gray')
plt.title("Zero‐Value Pixel Mask")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.imshow(depth_data, cmap='jet')   
plt.title("Depth")
plt.axis("off")
plt.colorbar(label="uint8 value")
plt.show()
