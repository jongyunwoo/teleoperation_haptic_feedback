# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
depth_data = np.load('/home/scilab/teleoperation/avp_teleoperate/teleop/utils/data/episode_0001/wrist_depths/000679_depth_0.npy')
print(depth_data.dtype)
print(depth_data)
print(depth_data.min(), depth_data.max())
zero_indices = np.argwhere(depth_data == 0)

print(f"Zero‐valued pixels: {zero_indices.shape[0]}")
zero_mask = (depth_data == 0)
# Out:
# (480, 640)
# uint16
# [[4764 4764 4764 ... 4418 4387 4387]
#  [4764 4764 4764 ... 4418 4387 4387]
#  [4764 4764 4764 ... 4387 4387 4387]
#  ...
#  [1990 1990 1989 ...  818  818  817]
#  [1990 1990 1988 ...  818  818  817]
#  [   0    0    0 ...  818  818  817]]
# 0 65535
# Zero‐valued pixels: 334

# %%
plt.figure(figsize=(6,4))
plt.imshow(zero_mask, cmap='gray')
plt.title("Zero‐Value Pixel Mask")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.imshow(depth_data, cmap='jet')   
plt.title("Depth")
plt.axis("off")
plt.colorbar(label="uint8 value")
plt.show()
